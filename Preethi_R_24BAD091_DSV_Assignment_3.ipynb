# %% [markdown]
# <a href="https://colab.research.google.com/github/PreethiR091/Preethi-R-24BAD091-DSV-Assignments/blob/main/Preethi_R_24BAD091_DSV_Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Description:
#
# This section performs the initial setup for Exploratory Data Analysis of the Heart Disease Prediction dataset. Required libraries such as Pandas, Matplotlib, and Seaborn are imported for data handling and visualization. The dataset is loaded and the first few records are displayed to understand the structure. Basic information and statistical summaries are generated to examine data types, feature ranges, and overall dataset characteristics.

# %%
# Exploratory Data Analysis (EDA)
# Heart Disease Prediction Dataset
print("Preethi R 24BAD091\n")

# Import required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set seaborn style for better visuals
sns.set(style="whitegrid")

# Load the dataset
df = pd.read_csv("Heart_Disease_Prediction.csv")

# Display first few rows
print(df.head())

# Dataset structure and data types
print(df.info())

# Statistical summary
print(df.describe())
# Out:
# Preethi R 24BAD091
#
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        3         3      Presence
# 1                        0         7       Absence
# ...

# %% [markdown]
# Description:
#
# The age distribution plot represents how patient ages are spread across the dataset. Most individuals fall within the middle-aged group, indicating that heart disease data is concentrated in this age range. This visualization helps identify dominant age groups and possible age-related risk trends.

# %%
# UNIVARIATE ANALYSIS

# 1. Age distribution (Histogram – Age Distribution)
sns.histplot(df["Age"], kde=True)
plt.title("Age Distribution")
plt.show()

# %% [markdown]
# Description:
#
# The age boxplot summarizes the central tendency and spread of age values. It highlights the median age, interquartile range, and potential outliers. Outliers may represent unusually young or elderly patients. This plot is useful for detecting age variability and extreme cases.

# %%
# 2. Age boxplot (Boxplot – Age Boxplot)
sns.boxplot(x=df["Age"])
plt.title("Age Boxplot")
plt.show()

# %% [markdown]
# Description:
#
# This plot displays the distribution of patients based on gender. It helps identify whether the dataset is balanced between males and females. Gender is an important demographic factor in heart disease analysis. The visualization supports gender-based comparative studies.

# %%
# 3. Sex distribution (Count Plot – Sex Distribution)
sns.countplot(x=df["Sex"])
plt.title("Sex Distribution")
plt.show()

# %% [markdown]
# Description:
#
# The chest pain type distribution shows the frequency of different chest pain categories. Certain chest pain types appear more frequently than others. Chest pain is a key diagnostic feature for heart disease. This plot helps identify dominant pain patterns in patients.

# %%
# 4. Chest pain type distribution (Count Plot – Chest Pain Type Distribution)
sns.countplot(x=df["Chest pain type"])
plt.title("Chest Pain Type Distribution")
plt.show()

# %% [markdown]
# Description:
#
# This histogram represents the distribution of resting blood pressure among patients. Most readings fall within a moderate range, while some extreme values indicate hypertension. Blood pressure is a major cardiovascular risk factor. The KDE curve highlights the density of values.

# %%
# 5. Resting blood pressure distribution (Histogram – Blood Pressure Distribution)
sns.histplot(df["BP"], kde=True)
plt.title("Blood Pressure Distribution")
plt.show()

# %% [markdown]
# Description:
#
# The blood pressure boxplot shows the spread and central tendency of BP values. It highlights median pressure levels and identifies outliers. High outliers indicate patients with severe hypertension. This visualization helps detect abnormal BP patterns.

# %%
# 6. Blood pressure boxplot (Boxplot – Blood Pressure Boxplot)
sns.boxplot(x=df["BP"])
plt.title("Blood Pressure Boxplot")
plt.show()

# %% [markdown]
# Description:
#
# This plot shows how cholesterol levels are distributed among patients. Higher cholesterol values are associated with increased heart disease risk. The KDE curve shows concentration of values. Extreme values indicate unhealthy lipid profiles.

# %%
# 7. Cholesterol distribution (Histogram – Cholesterol Distribution)
sns.histplot(df["Cholesterol"], kde=True)
plt.title("Cholesterol Distribution")
plt.show()

# %% [markdown]
# Description:
#
# The cholesterol boxplot summarizes cholesterol variability. It highlights median cholesterol levels and outliers. Outliers indicate patients with very high cholesterol. This plot helps in identifying lipid abnormalities.

# %%
# 8. Cholesterol boxplot (Boxplot – Cholesterol Boxplot)
sns.boxplot(x=df["Cholesterol"])
plt.title("Cholesterol Boxplot")
plt.show()

# %% [markdown]
# Description:
#
# This plot shows the count of patients based on fasting blood sugar levels. Elevated fasting blood sugar may indicate diabetes. Diabetes is a strong risk factor for heart disease. The plot helps understand metabolic risk distribution.

# %%
# 9. Fasting blood sugar distribution (Count Plot – Fasting Blood Sugar)
sns.countplot(x=df["FBS over 120"])
plt.title("Fasting Blood Sugar")
plt.show()

# %% [markdown]
# Description:
#
# This plot displays different resting ECG results observed in patients. ECG abnormalities can indicate cardiac dysfunction. Certain ECG patterns occur more frequently. This visualization helps in cardiac signal interpretation.

# %%
# 10. Resting ECG results (Count Plot – Resting ECG Results)
sns.countplot(x=df["EKG results"])
plt.title("Resting ECG Results")
plt.show()

# %% [markdown]
# Description:
#
# This histogram shows the distribution of maximum heart rate achieved. Lower maximum heart rate may indicate cardiac limitations. The KDE curve shows density concentration. This feature is important for exercise tolerance assessment.

# %%
# 11. Maximum heart rate distribution (Histogram – Maximum Heart Rate Distribution)
sns.histplot(df["Max HR"], kde=True)
plt.title("Maximum Heart Rate Distribution")
plt.show()

# %% [markdown]
# Description:
#
# The boxplot shows the spread of maximum heart rate values. It highlights median performance and outliers. Lower outliers may indicate poor cardiac response. Useful for identifying abnormal exercise responses.

# %%
# 12. Max heart rate boxplot (Boxplot – Maximum Heart Rate Boxplot)
sns.boxplot(x=df["Max HR"])
plt.title("Maximum Heart Rate Boxplot")
plt.show()

# %% [markdown]
# Description:
#
# This plot shows the occurrence of exercise-induced angina. Angina during exercise is a strong indicator of heart disease. A higher count suggests cardiac stress. This feature is clinically significant.

# %%
# 13. Exercise induced angina (Count Plot – Exercise Induced Angina)
sns.countplot(x=df["Exercise angina"])
plt.title("Exercise Induced Angina")
plt.show()

# %% [markdown]
# Description:
#
# This plot displays the distribution of ST depression values. Higher ST depression indicates abnormal ECG responses. The KDE curve highlights density. It is a critical indicator of ischemia.

# %%
# 14. ST depression distribution (Histogram – ST Depression Distribution)
sns.histplot(df["ST depression"], kde=True)
plt.title("ST Depression Distribution")
plt.show()

# %% [markdown]
# Description:
#
# The boxplot summarizes ST depression variability. It highlights median levels and extreme cases. Higher outliers may indicate severe ischemia. This plot helps detect abnormal ECG behavior.

# %%
# 15. ST depression boxplot (Boxplot – ST Depression Boxplot)
sns.boxplot(x=df["ST depression"])
plt.title("ST Depression Boxplot")
plt.show()

# %% [markdown]
# Description:
#
# This plot shows the distribution of different ST segment slopes. The slope indicates how the ST segment behaves during stress. Certain slopes are associated with heart disease. This visualization helps interpret ECG patterns.

# %%
# 16. Slope of ST segment (Count Plot – Slope of ST Segment)
sns.countplot(x=df["Slope of ST"])
plt.title("Slope of ST Segment")
plt.show()

# %% [markdown]
# Description:
#
# This plot displays the number of major vessels observed through fluoroscopy. A higher number indicates more severe blockage. This feature reflects the extent of coronary artery disease. It is a strong diagnostic indicator.

# %%
# 17. Number of major vessels (Count Plot – Number of Major Vessels)
sns.countplot(x=df["Number of vessels fluro"])
plt.title("Number of Major Vessels")
plt.show()

# %% [markdown]
# Description:
#
# This visualization shows the distribution of thallium stress test results. Abnormal thallium values indicate poor blood flow. It is widely used in heart disease diagnosis. The plot helps identify abnormal cases.

# %%
# 18. Thallium test results (Count Plot – Thallium Test Results)
sns.countplot(x=df["Thallium"])
plt.title("Thallium Test Results")
plt.show()

# %% [markdown]
# Description:
#
# This plot shows the number of patients with and without heart disease. It helps identify class imbalance in the dataset. Understanding class distribution is important before model training. This plot represents the target variable.

# %%
# 19. Heart disease target variable (Count Plot – Heart Disease Distribution)
sns.countplot(x=df["Heart Disease"])
plt.title("Heart Disease Distribution")
plt.show()

# %% [markdown]
# Description:
#
# This boxplot compares age distribution between heart disease classes. Patients with heart disease tend to be older. The median age differs between classes. This plot highlights age as a major risk factor.

# %%
# 20. Age vs Heart Disease (Boxplot – Age vs Heart Disease)
sns.boxplot(x=df["Heart Disease"], y=df["Age"])
plt.title("Age vs Heart Disease")
plt.show()

# %% [markdown]
# Description:
#
# This plot compares heart disease occurrence across genders. It helps identify gender-based risk differences. Often, males show higher prevalence. This visualization supports demographic analysis.

# %%
# 21. Sex vs Heart Disease (Count Plot – Sex vs Heart Disease)
sns.countplot(x=df["Sex"], hue=df["Heart Disease"])
plt.title("Sex vs Heart Disease")
plt.show()

# %% [markdown]
# Description:
#
# This plot shows the relationship between chest pain type and heart disease. Certain pain types strongly correlate with disease presence. It is one of the most important diagnostic features. This visualization aids clinical understanding.

# %%
# 22. Chest pain vs Heart Disease (Count Plot – Chest Pain vs Heart Disease)
sns.countplot(x=df["Chest pain type"], hue=df["Heart Disease"])
plt.title("Chest Pain vs Heart Disease")
plt.show()

# %% [markdown]
# Description:
#
# This boxplot compares blood pressure values between disease classes. Higher BP is commonly associated with heart disease. Outliers show hypertensive patients. This plot highlights BP as a cardiovascular risk factor.

# %%
# 23. Blood pressure vs Heart Disease (Boxplot – BP vs Heart Disease)
sns.boxplot(x=df["Heart Disease"], y=df["BP"])
plt.title("BP vs Heart Disease")
plt.show()

# %% [markdown]
# Description:
#
# This plot compares cholesterol levels across heart disease categories. Patients with heart disease often show higher cholesterol. The median and spread differ between classes. This plot emphasizes cholesterol as a risk factor.

# %%
# 24. Cholesterol vs Heart Disease (Boxplot – Cholesterol vs Heart Disease)
sns.boxplot(x=df["Heart Disease"], y=df["Cholesterol"])
plt.title("Cholesterol vs Heart Disease")
plt.show()

# %% [markdown]
# Description:
#
# This plot shows fasting blood sugar levels across heart disease classes. Elevated blood sugar increases cardiac risk. It helps identify metabolic influence on heart disease. This visualization supports diabetes-related analysis.

# %%
# 25. Fasting blood sugar vs Heart Disease (Count Plot – FBS vs Heart Disease)
sns.countplot(x=df["FBS over 120"], hue=df["Heart Disease"])
plt.title("FBS vs Heart Disease")
plt.show()

# %% [markdown]
# Description:
#
# This boxplot compares maximum heart rate values between disease classes. Patients with heart disease often have lower max heart rates. The plot highlights differences in exercise tolerance. It is useful for functional assessment.

# %%
# 26. Max heart rate vs Heart Disease (Boxplot – Max HR vs Heart Disease)
sns.boxplot(x=df["Heart Disease"], y=df["Max HR"])
plt.title("Max HR vs Heart Disease")
plt.show()

# %% [markdown]
# Description:
#
# This plot shows the relationship between exercise-induced angina and heart disease. Presence of angina strongly correlates with disease. It highlights cardiac stress during activity. This is a key clinical indicator.

# %%
# 27. Exercise angina vs Heart Disease (Count Plot – Exercise Angina vs Heart Disease)
sns.countplot(x=df["Exercise angina"], hue=df["Heart Disease"])
plt.title("Exercise Angina vs Heart Disease")
plt.show()

# %% [markdown]
# Description:
#
# This boxplot compares ST depression values between disease groups. Higher ST depression is linked to heart disease. It reflects ECG abnormalities. This plot aids in identifying ischemic patterns.

# %%
# 28. ST depression vs Heart Disease (Boxplot – ST Depression vs Heart Disease)
sns.boxplot(x=df["Heart Disease"], y=df["ST depression"])
plt.title("ST Depression vs Heart Disease")
plt.show()

# %% [markdown]
# Description:
#
# This plot shows the relationship between thallium test results and heart disease. Abnormal thallium values indicate reduced blood flow. It is a strong diagnostic feature. This visualization supports medical interpretation.

# %%
# 29. Thallium vs Heart Disease (Count Plot – Thallium vs Heart Disease)
sns.countplot(x=df["Thallium"], hue=df["Heart Disease"])
plt.title("Thallium vs Heart Disease")
plt.show()

# %% [markdown]
# Description:
# This scatter plot shows the relationship between age and blood pressure. Blood pressure generally increases with age. Color indicates heart disease presence. This plot helps detect age-related BP patterns.

# %%
# 30. Age vs BP (Scatter Plot – Age vs BP)
sns.scatterplot(x=df["Age"], y=df["BP"], hue=df["Heart Disease"])
plt.title("Age vs BP")
plt.show()

# %% [markdown]
# Description:
#
# This scatter plot displays cholesterol variation across different ages. Older patients often show higher cholesterol levels. Disease cases are highlighted using color. This plot helps identify lifestyle risk trends.

# %%
# 31. Age vs Cholesterol (Scatter Plot – Age vs Cholesterol)
sns.scatterplot(x=df["Age"], y=df["Cholesterol"], hue=df["Heart Disease"])
plt.title("Age vs Cholesterol")
plt.show()

# %% [markdown]
# Description:
#
# This scatter plot shows how maximum heart rate changes with age. Max heart rate generally decreases as age increases. Heart disease cases are highlighted. This plot helps assess age-related cardiac fitness.

# %%
# 32. Age vs Max HR (Scatter Plot – Age vs Max HR)
sns.scatterplot(x=df["Age"], y=df["Max HR"], hue=df["Heart Disease"])
plt.title("Age vs Max HR")
plt.show()

# %% [markdown]
# Description:
#
# This plot shows the relationship between blood pressure and cholesterol. Higher values of both increase heart disease risk. Disease cases are color-coded. This plot helps identify combined risk factors.

# %%
# 33. BP vs Cholesterol (Scatter Plot – BP vs Cholesterol)
sns.scatterplot(x=df["BP"], y=df["Cholesterol"], hue=df["Heart Disease"])
plt.title("BP vs Cholesterol")
plt.show()

# %% [markdown]
# Description:
#
# This scatter plot shows the relationship between max heart rate and ST depression. Lower max HR with higher ST depression indicates cardiac issues. Disease cases are highlighted. This visualization supports ECG-based analysis.

# %%
# 34. Max HR vs ST Depression (Scatter Plot – Max HR vs ST Depression)
sns.scatterplot(x=df["Max HR"], y=df["ST depression"], hue=df["Heart Disease"])
plt.title("Max HR vs ST Depression")
plt.show()

# %% [markdown]
# Description:
#
# The correlation heatmap displays relationships between numerical variables. Only numeric columns are used to avoid conversion errors. Strong correlations help in feature selection. This plot is essential for predictive modeling.

# %%
# 35. Correlation heatmap (Heatmap – Correlation Heatmap)
numeric_df = df.select_dtypes(include=["int64", "float64"])
plt.figure(figsize=(10, 8))
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Description:
#
# The pairplot shows relationships between multiple variables simultaneously. It helps visualize feature interactions. Color coding represents heart disease presence. This plot is useful for multivariate pattern detection.

# %%
# 36. Pairplot (Pair Plot – Multivariate Relationships)
sns.pairplot(df, hue="Heart Disease")
plt.show()

# %% [markdown]
# Description:
#
# This violin plot shows age distribution across heart disease classes. It combines density and boxplot features. Wider areas indicate higher data density. This plot gives deeper insight into age variation.

# %%
# 37. Age vs Heart Disease (Violin Plot – Age vs Heart Disease)
sns.violinplot(x=df["Heart Disease"], y=df["Age"])
plt.title("Age vs Heart Disease (Violin Plot)")
plt.show()

# %% [markdown]
# Description:
#
# This violin plot shows blood pressure distribution for heart disease classes. It highlights density and spread of BP values. Differences between classes are clearly visible. This plot enhances BP risk analysis.

# %%
# 38. BP vs Heart Disease (Violin Plot – BP vs Heart Disease)
sns.violinplot(x=df["Heart Disease"], y=df["BP"])
plt.title("BP vs Heart Disease (Violin Plot)")
plt.show()

# %% [markdown]
# Description:
#
# This violin plot visualizes cholesterol density across disease classes. It highlights distribution shape and concentration. Higher density at upper values indicates increased risk. This plot aids cholesterol-based interpretation.

# %%
# 39. Cholesterol vs Heart Disease (Violin Plot – Cholesterol vs Heart Disease)
sns.violinplot(x=df["Heart Disease"], y=df["Cholesterol"])
plt.title("Cholesterol vs Heart Disease (Violin Plot)")
plt.show()

# %% [markdown]
# Description:
#
# This strip plot shows individual age points for each heart disease class. It highlights data spread and clustering. Overlapping points show dense regions. This plot helps visualize raw age distribution.

# %%
# 40. Age vs Heart Disease (Strip Plot – Age vs Heart Disease)
sns.stripplot(x=df["Heart Disease"], y=df["Age"])
plt.title("Age vs Heart Disease (Strip Plot)")
plt.show()

# %% [markdown]
# Description:
#
# This strip plot shows individual max heart rate values by disease class. It highlights clustering and spread. Lower values are common in disease cases. This plot supports performance comparison.

# %%
# 41. Max HR vs Heart Disease (Strip Plot – Max HR vs Heart Disease)
sns.stripplot(x=df["Heart Disease"], y=df["Max HR"])
plt.title("Max HR vs Heart Disease (Strip Plot)")
plt.show()

# %% [markdown]
# Description:
#
# This KDE plot shows age density curves for heart disease classes. It highlights how age distribution differs between groups. Overlapping regions show shared age ranges. This plot provides smooth density comparison.

# %%
# 42. Age density by Heart Disease (KDE Plot – Age Density)
sns.kdeplot(data=df, x="Age", hue="Heart Disease", fill=True)
plt.title("Age Density by Heart Disease")
plt.show()

# %% [markdown]
# Description:
#
# This KDE plot displays cholesterol density for heart disease categories. It highlights differences in cholesterol concentration. Higher density at elevated values indicates risk. This visualization supports lipid analysis.

# %%
# 43. Cholesterol density by Heart Disease (KDE Plot – Cholesterol Density)
sns.kdeplot(data=df, x="Cholesterol", hue="Heart Disease", fill=True)
plt.title("Cholesterol Density by Heart Disease")
plt.show()
